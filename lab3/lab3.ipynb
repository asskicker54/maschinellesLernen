# %%
import pandas as pd

# %%
df = pd.read_excel('ATEROSKLEROZ++10.02.23.xls')
df
# Out:
#       Болен/Здоров     № GPx1 MnSOD MTHFR MTR CAT TP53 GSTP105 GSTP114  ...  \
# 0     АТЕРОСКЛЕРОЗ     1   CC    CC    CT  AA  CT   CC      GG      CC  ...
# 1     АТЕРОСКЛЕРОЗ     2   CT    TT    CC  AA  CC   GC      AG      CC  ...
# 2     АТЕРОСКЛЕРОЗ     3   CT    CT    CC  AG  CC   GC      AG      CC  ...
# 3     АТЕРОСКЛЕРОЗ     4   CC    CC    CC  AG  CC   GC      AG      CT  ...
# 4     АТЕРОСКЛЕРОЗ     5   CT    CT    CC  AG  CC   GG      GG      CT  ...
# ...            ...   ...  ...   ...   ...  ..  ..  ...     ...     ...  ...
# 1468        Здоров  1487   СС    СТ    СС  АА  CT   GC      AG      CT  ...
# 1469        Здоров  1488   ТТ    ТТ    СТ  АА  CT   GC      AA      CC  ...
# 1470        Здоров  1489   СТ    СС    СС  АА  CT   GG      AA      CC  ...
# 1471        Здоров  1490   СС    СТ    СС  AG  CC   GC      AG      CC  ...
# 1472        Здоров  1491   СТ    ТТ    СС  AG  CC   GG      AA      CC  ...
#
# ...

# %%
print(f'{df.isna().sum()}/n/n{df.count()}')
# Out:
# Болен/Здоров         0
# №                    0
# GPx1                73
# MnSOD              128
# MTHFR              420
#                   ...
# ОАК эритроциты     945
# ОАК лейкоциты      945
# С                  993
# П.                1128
# Тр                 950
# Length: 98, dtype: int64 /n/n Болен/Здоров      1473
# №                 1473
# GPx1              1400
# MnSOD             1345
# MTHFR             1053
#                   ...
# ОАК эритроциты     528
# ОАК лейкоциты      528
# С                  480
# П.                 345
# Тр                 523
# Length: 98, dtype: int64
